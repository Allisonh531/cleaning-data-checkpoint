# %% [markdown]
# # Checkpoint Three: Cleaning Data
#
# Now you are ready to clean your data. Before starting coding, provide the link to your dataset below.
#
# My dataset:https://www.kaggle.com/datasets/felipeesc/shark-attack-dataset
#
# Import the necessary libraries and create your dataframe(s).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib

# %%
sharks_df=pd.read_csv(r'C:/Users/Admin/Desktop/LaunchCode/Sharks.csv',encoding='cp1252')

sharks_df.head(40)
pd.set_option('display.max_rows',300)
# Out:
#      Case Number                  Date    Year          Type        Country  \
# 0     2018.06.25             25-Jun-18  2018.0       Boating            USA
# 1     2018.06.18             18-Jun-18  2018.0    Unprovoked            USA
# 2     2018.06.09              9-Jun-18  2018.0       Invalid            USA
# 3     2018.06.08              8-Jun-18  2018.0    Unprovoked      AUSTRALIA
# 4     2018.06.04              4-Jun-18  2018.0      Provoked         MEXICO
# 5   2018.06.03.b              3-Jun-18  2018.0    Unprovoked      AUSTRALIA
# 6   2018.06.03.a              3-Jun-18  2018.0    Unprovoked         BRAZIL
# 7     2018.05.27             27-May-18  2018.0    Unprovoked            USA
# 8   2018.05.26.b             26-May-18  2018.0    Unprovoked            USA
# 9   2018.05.26.a             26-May-18  2018.0    Unprovoked            USA
# 10    2018.05.24             24-May-18  2018.0      Provoked      AUSTRALIA
# ...

# %%
sharks_df
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25    25-Jun-18  2018.0     Boating                 USA
# 1     2018.06.18    18-Jun-18  2018.0  Unprovoked                 USA
# 2     2018.06.09     9-Jun-18  2018.0     Invalid                 USA
# 3     2018.06.08     8-Jun-18  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04     4-Jun-18  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %% [markdown]
# ## Missing Data
#
# Test your dataset for missing data and handle it as needed. Make notes in the form of code comments as to your thought process.

# %%
sharks_df['Year'].value_counts()
# Out:
# 2015.0    143
# 2017.0    136
# 2016.0    130
# 2011.0    128
# 2014.0    127
# 0.0       125
# 2013.0    122
# 2008.0    122
# 2009.0    120
# 2012.0    117
# 2007.0    112
# 2006.0    103
# 2005.0    103
# 2010.0    101
# 2000.0     97
# 1960.0     93
# 1959.0     93
# 2003.0     92
# 2004.0     92
# 2001.0     92
# 2002.0     88
# 1962.0     86
# 1961.0     78
# 1995.0     76
# 1964.0     66
# 1999.0     66
# 1998.0     65
# 1996.0     61
# 1963.0     61
# 1966.0     58
# 1997.0     57
# 1993.0     56
# 1992.0     56
# 1994.0     56
# 1988.0     55
# 1958.0     54
# 2018.0     53
# 1989.0     53
# 1956.0     51
# 1965.0     51
# 1983.0     50
# 1981.0     49
# 1975.0     49
# 1967.0     48
# 1968.0     47
# 1950.0     43
# 1955.0     43
# 1954.0     42
# 1970.0     42
# 1942.0     41
# 1984.0     41
# 1957.0     41
# 1982.0     40
# 1986.0     39
# 1976.0     39
# 1974.0     38
# 1990.0     38
# 1991.0     38
# 1929.0     38
# 1985.0     37
# 1953.0     36
# 1980.0     35
# ...

# %%
year_zero=sharks_df.loc[sharks_df['Year']==0,'Date']
year_zero
# Out:
# 6177                                         Ca. 214 B.C.
# 6178                                        Ca. 336.B.C..
# 6179                                             493 B.C.
# 6180                                         Ca. 725 B.C.
# 6181                                          Before 1939
# 6182                                         1990 or 1991
# 6183                                          Before 2016
# 6184                                      Before Oct-2009
# 6185                                          Before 1934
# 6186                                          Before 1934
# 6187                                                2009?
# 6188                                          Before 1930
# 6189                                            1880-1899
# 6190                                          Before 1909
# 6191                                          Before 2012
# 6192                                          Before 1916
# ...

# %%
sharks_df['Age'].isnull().sum()
# Out:
# 22252

# %%
sharks_df['Age'].fillna(0)
# Out:
# 0        57
# 1        11
# 2        48
# 3         0
# 4         0
#          ..
# 25718     0
# 25719     0
# 25720     0
# 25721     0
# 25722     0
# Name: Age, Length: 25723, dtype: object

# %%
sharks_df['Species '].fillna('NA')
# Out:
# 0            White shark
# 1                     NA
# 2                     NA
# 3              2 m shark
# 4        Tiger shark, 3m
#               ...
# 25718                 NA
# 25719                 NA
# 25720                 NA
# 25721                 NA
# 25722                 NA
# Name: Species , Length: 25723, dtype: object

# %%
sharks_df['Area'].isnull().sum()
# Out:
# 19876

# %%
sharks_df['Area'].fillna('NA')
# Out:
# 0             California
# 1                Georgia
# 2                 Hawaii
# 3        New South Wales
# 4                 Colima
#               ...
# 25718                 NA
# 25719                 NA
# 25720                 NA
# 25721                 NA
# 25722                 NA
# Name: Area, Length: 25723, dtype: object

# %%
sharks_df['Time'].fillna('NA')
# Out:
# 0                18h00
# 1        14h00  -15h00
# 2                07h45
# 3                   NA
# 4                   NA
#              ...
# 25718               NA
# 25719               NA
# 25720               NA
# 25721               NA
# 25722               NA
# Name: Time, Length: 25723, dtype: object

# %%
sharks_df['Sex '].isnull().sum()
# Out:
# 19986

# %%
sharks_df['Sex '].value_counts()
# Out:
# M      5094
# F       637
# M         2
# N         2
# lli       1
# .         1
# Name: Sex , dtype: int64

# %%
sharks_df['Sex '].fillna('U').head(40)
# Out:
# 0     F
# 1     F
# 2     M
# 3     M
# 4     M
# 5     M
# 6     M
# 7     M
# 8     M
# 9     M
# 10    M
# 11    M
# 12    M
# 13    M
# 14    F
# 15    M
# 16    M
# 17    M
# 18    M
# 19    M
# 20    M
# 21    M
# 22    M
# 23    M
# 24    M
# 25    M
# 26    M
# 27    M
# 28    M
# 29    M
# 30    M
# 31    M
# 32    U
# 33    M
# 34    M
# 35    M
# 36    M
# 37    M
# 38    M
# 39    M
# Name: Sex , dtype: object

# %%
sharks_df['Sex '].value_counts()
# Out:
# M      5094
# F       637
# M         2
# N         2
# lli       1
# .         1
# Name: Sex , dtype: int64

# %% [markdown]
# ## Irregular Data
#
# Detect outliers in your dataset and handle them as needed. Use code comments to make notes about your thought process.

# %%
sharks_df.describe()
# Out:
#               Year  original order
# count  6300.000000     6309.000000
# mean   1927.272381     3155.999683
# std     281.116308     1821.396206
# min       0.000000        2.000000
# 25%    1942.000000     1579.000000
# 50%    1977.000000     3156.000000
# 75%    2005.000000     4733.000000
# max    2018.000000     6310.000000

# %% [markdown]
# ## Unnecessary Data
#
# Look for the different types of unnecessary data in your dataset and address it as needed. Make sure to use code comments to illustrate your thought process.

# %%
#sharks_df.drop(['pdf','href','href formula','Case Number.1','Case Number.2','original order','Unnamed: 22','Unnamed: 23'],axis=1)
#removed unnessasary columns

# %%
sharks_df.drop(sharks_df.index[6302:25723],inplace=True)
#removed columns with all NA

# %%
sharks_df=sharks_df[sharks_df['Fatal (Y/N)']!='2017']
#remove the row that has value 2017 in the column fatal (Y/N)

# %%
sharks_df=sharks_df[sharks_df['Fatal (Y/N)']!='M']
#remove the row that has value M in column fatal (Y/N)

# %%
sharks_df=sharks_df.drop(['pdf','href','href formula','Case Number.1','Case Number.2','original order','Unnamed: 22','Unnamed: 23'],axis=1)
#removed unnessasary columns

# %% [markdown]
# ## Inconsistent Data
#
# Check for inconsistent data and address any that arises. As always, use code comments to illustrate your thought process.

# %%
sharks_df['Fatal (Y/N)'] = sharks_df['Fatal (Y/N)'].str.replace('N ', 'N')

# %%
sharks_df['Fatal (Y/N)'] = sharks_df['Fatal (Y/N)'].str.replace(' N', 'N')

# %%
sharks_df['Fatal (Y/N)'] = sharks_df['Fatal (Y/N)'].str.replace('y', 'Y')

# %%
sharks_df['Fatal (Y/N)'].value_counts()
# Out:
# N          4301
# Y          1389
# UNKNOWN      71
# Name: Fatal (Y/N), dtype: int64

# %%
sharks_df['Sex '].value_counts()
# Out:
# M      5092
# F       637
# M         2
# N         2
# lli       1
# .         1
# Name: Sex , dtype: int64

# %%
sharks_df['Sex ']=sharks_df['Sex '].str.replace('M ','M')

# %%
sharks_df['Sex ']=sharks_df['Sex '].str.replace('lli','U')

# %%
sharks_df['Sex ']=sharks_df['Sex '].str.replace('.','U')
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_22412/2067417685.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   sharks_df['Sex ']=sharks_df['Sex '].str.replace('.','U')

# %%
sharks_df['Sex ']=sharks_df['Sex '].str.replace('N','U')

# %%
#changed the incorrect input in sex column to U stands for unknown

# %% [markdown]
# ## Summarize Your Results
#
# Make note of your answers to the following questions.
#
# 1. Did you find all four types of dirty data in your dataset?
# 2. Did the process of cleaning your data give you new insights into your dataset?
# 3. Is there anything you would like to make note of when it comes to manipulating the data and making visualizations?

# %%
#1. I couldn't find irregular data but all the other types of dirty data was found and fixed
#2. I did notice there is mostly string columns 
#3. when making viz lookout for years and dates
